# %%
import pandas as pd

acc = pd.read_csv('../../data/crm/accounts.csv')
prod = pd.read_csv('../../data/crm/products.csv')
aes = pd.read_csv('../../data/crm/sales_teams.csv')
pipe = pd.read_csv('../../data/crm/sales_pipeline.csv')

df = pipe.merge(acc, on='account').merge(prod, on='product').merge(aes, on='sales_agent')

# %%
df
# Out:
#      opportunity_id        sales_agent         product    account  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic    Cancity
# 1          EC4QE1BX    Darcel Schlecht      MG Special    Cancity
# 2          MV1LWRNH        Moses Frase       GTX Basic    Codehow
# 3          PE84CX4O          Zane Levy       GTX Basic     Hatfan
# 4          ZNBS69V1      Anna Snelling      MG Special   Ron-tech
# ...             ...                ...             ...        ...
# 6112       VW8CEV4C  Versie Hillebrand      MG Special  Konmatfix
# 6113       KLUS7RVS  Versie Hillebrand      MG Special   Opentech
# 6114       ROM4I2T0  Versie Hillebrand      MG Special  Rundofase
# 6115       FCNN6UY0  Versie Hillebrand     MG Advanced  Ganjaflex
# 6116       8M2O0Q8V  Versie Hillebrand     MG Advanced      Silis
#
#        deal_stage engage_date  close_date  close_value     sector  \
# 0             Won  2016-10-20  2017-03-01       1054.0     retail
# ...
